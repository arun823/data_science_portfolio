# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house=pd.read_csv(r'D:\python data file\5. London Housing Data.csv')

# %%
house.head(2)
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
house.shape
# Out:
# (13549, 6)

# %%
house.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
sns.heatmap(house.isnull())
plt.show()

# %%
house.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
house.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
house.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
# we have to convert data type of date column into date time so that we can extract seprately month and year column

# %%
house['date'] = pd.to_datetime(house['date'])

# %%
house.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %%
house.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
# now add another column name year which contains year only

# %%
house['year'] = house['date'].dt.year

# %%
house.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
# add another column name month  which contain month only

# %%
house['month'] = house['date'].dt.month

# %%
house.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year  month
# 0           NaN  1995      1
# 1           NaN  1995      2

# %%
# add another column name month in '2' column which contain month only

# %%
house.insert(1 , 'months', house['date'].dt.month)

# %%
house.head(50)
# Out:
#          date  months            area  average_price       code  houses_sold  \
# 0  1995-01-01       1  city of london          91449  E09000001         17.0
# 1  1995-02-01       2  city of london          82203  E09000001          7.0
# 2  1995-03-01       3  city of london          79121  E09000001         14.0
# 3  1995-04-01       4  city of london          77101  E09000001          7.0
# 4  1995-05-01       5  city of london          84409  E09000001         10.0
# 5  1995-06-01       6  city of london          94901  E09000001         17.0
# 6  1995-07-01       7  city of london         110128  E09000001         13.0
# 7  1995-08-01       8  city of london         112329  E09000001         14.0
# 8  1995-09-01       9  city of london         104473  E09000001         17.0
# 9  1995-10-01      10  city of london         108038  E09000001         14.0
# 10 1995-11-01      11  city of london         117636  E09000001         11.0
# ...

# %%
# drop or remove months , year , month , columns

# %%
house.drop(columns = ['months', 'year', 'month'] , inplace = True)

# %%
house.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
# show all records of no of crimes = 0 and how many such records

# %%
len(house[house['no_of_crimes'] == 0])
# Out:
# 104

# %%
house[house['no_of_crimes'] == 0].value_counts().sum()
# Out:
# 104

# %%
# what is max and min avg price per year in england

# %%
df1 = house.groupby('area').get_group('england')

# %%
df1.shape
# Out:
# (301, 6)

# %%
 df1['years'] = df1['date'].dt.year
# Out:
# <ipython-input-32-3afec5ec098a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['years'] = df1['date'].dt.year

# %%
df1.head(50)
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# 13253 1995-06-01  england          53735  E92000001      72640.0
# 13254 1995-07-01  england          53901  E92000001      64242.0
# 13255 1995-08-01  england          53600  E92000001      69269.0
# 13256 1995-09-01  england          53309  E92000001      67251.0
# 13257 1995-10-01  england          52845  E92000001      61264.0
# 13258 1995-11-01  england          52788  E92000001      63955.0
# 13259 1995-12-01  england          52922  E92000001      69345.0
# 13260 1996-01-01  england          52333  E92000001      48694.0
# ...

# %%
df1.groupby('years')['average_price'].min()
# Out:
# years
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
house['date'] = pd.to_datetime(house['date'])

# %%
house.columns
# Out:
# Index(['date', 'area', 'average_price', 'code', 'houses_sold', 'no_of_crimes'], dtype='object')

# %%
house.head(1)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
#
#    no_of_crimes
# 0           NaN

# %%
df2 = house[house['area'] == 'england']

# %%
df2['year'] = df2['date'].dt.year
# Out:
# <ipython-input-39-95696ea2b09c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year'] = df2['date'].dt.year

# %%
df2.head(1)
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
#
#        no_of_crimes  year
# 13248           NaN  1995

# %%
df2.groupby('year')['average_price'].min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64
