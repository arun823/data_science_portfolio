# %%
import pandas as pd

# %%
cov=pd.read_csv(r'D:\python data file\4. covid_19_data.csv')

# %%
cov.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
cov.shape
# Out:
# (321, 6)

# %%
cov.nunique()
# Out:
# Date           1
# State        137
# Region       187
# Confirmed    282
# Deaths       142
# Recovered    195
# dtype: int64

# %%
cov.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
cov.notnull().sum()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
cov.sort_values(by ='Recovered' , ascending = False )
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]

# %%
cov.groupby('Region')['Recovered'].sum().sort_values(ascending=False)
# Out:
# Region
# Spain               132929
# US                  120720
# Germany             120400
# Mainland China       77610
# Iran                 73791
#                      ...
# Cabo Verde               2
# Yemen                    1
# South Sudan              0
# Papua New Guinea         0
# MS Zaandam               0
# Name: Recovered, Length: 187, dtype: int64

# %%
cov.groupby('Region')['Recovered','Confirmed'].describe()
# Out:
# <ipython-input-40-7103100ec5a5>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cov.groupby('Region')['Recovered','Confirmed'].describe()
#                    Recovered                                              \
#                        count    mean std     min     25%     50%     75%
# Region
# Afghanistan              1.0   252.0 NaN   252.0   252.0   252.0   252.0
# Albania                  1.0   455.0 NaN   455.0   455.0   455.0   455.0
# Algeria                  1.0  1702.0 NaN  1702.0  1702.0  1702.0  1702.0
# Andorra                  1.0   423.0 NaN   423.0   423.0   423.0   423.0
# Angola                   1.0     7.0 NaN     7.0     7.0     7.0     7.0
# ...                      ...     ...  ..     ...     ...     ...     ...
# West Bank and Gaza       1.0    71.0 NaN    71.0    71.0    71.0    71.0
# Western Sahara           1.0     5.0 NaN     5.0     5.0     5.0     5.0
# ...

# %%
cov.groupby('Region')['Recovered','Confirmed'].sum()
# Out:
# <ipython-input-41-f5e50de07fcc>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cov.groupby('Region')['Recovered','Confirmed'].sum()
#                     Recovered  Confirmed
# Region
# Afghanistan               252       1939
# Albania                   455        766
# Algeria                  1702       3848
# Andorra                   423        743
# Angola                      7         27
# ...                       ...        ...
# West Bank and Gaza         71        344
# Western Sahara              5          6
# Yemen                       1          6
# Zambia                     54         97
# Zimbabwe                    5         32
#
# [187 rows x 2 columns]

# %%
cov.groupby('Region')['Recovered'].sum().sort_values()
# Out:
# Region
# Papua New Guinea         0
# South Sudan              0
# MS Zaandam               0
# Yemen                    1
# Cabo Verde               2
#                      ...
# Iran                 73791
# Mainland China       77610
# Germany             120400
# US                  120720
# Spain               132929
# Name: Recovered, Length: 187, dtype: int64

# %%
cov[~(cov['Confirmed']<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
cov.shape
# Out:
# (321, 6)

# %%
cov = cov[~(cov['Confirmed']<10)]

# %%
cov.shape
# Out:
# (304, 6)

# %%
cov.groupby('Region')['Deaths'].sum().sort_values(ascending=False)
# Out:
# Region
# US                          60967
# Italy                       27682
# UK                          26165
# Spain                       24275
# France                      24121
#                             ...
# Mozambique                      0
# Mongolia                        0
# Central African Republic        0
# Cambodia                        0
# Grenada                         0
# Name: Deaths, Length: 180, dtype: int64

# %%
cov.groupby('Region').get_group('India')
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
cov=pd.read_csv(r'D:\python data file\4. covid_19_data.csv')

# %%
cov.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(cov.isnull())
plt.show()
